# %%
# elif 사용하기 else if

x = 20

if x==10:
    print("10입니다.")
elif x == 20:
    print("20입니다.")
else:
    print("아닙니다.")
# Out:
# 20입니다.

# %%
x = 30

if x==10:
    print("10입니다.")
elif x == 20:
    print("20입니다.")
else:
    print("10도 아니고 20도 아닙니다.")
# Out:
# 10도 아니고 20도 아닙니다.

# %%
x = 30

if x==10:
    print("10입니다.")
else: # else는 마지막에 와야한다.
    print("10도 아니고 20도 아닙니다.")
elif x == 20: 
    print("20입니다.")
# Out:
#   Cell In[6], line 7
#     elif x == 20:
#     ^
# SyntaxError: 'elif' block follows an 'else' block

# %%
# 음료수 자판기

button = int(input())

if button == 1:
    print("콜라")
elif button == 2:
    print("사이다")
elif button == 3:
    print("환타")
else:
    print("제공하지 않는 메뉴")
# Out:
# 제공하지 않는 메뉴

# %%
card = 9000

age = int(input())

if 7 < age <= 12:
    card = card - 650
elif 13 < age <= 18:
    card = card - 1050
elif 19<= age:
    card = card - 1250

print(card)
# Out:
# 8350
