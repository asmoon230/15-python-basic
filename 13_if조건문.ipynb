# %%
x = 10

if x == 10:
    print("10입니다.")
# Out:
# 10입니다.

# %%
x = 10

if x == 10:
    
print("10입니다.")
# Out:
#   Cell In[5], line 5
#     print("10입니다.")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
x = 10

if x == 10:
    pass
print("10입니다.")
# Out:
# 10입니다.

# %%
x = 10

if x == 10:
    print("x에 들어있는 숫자는")
    print("10입니다.")
# Out:
# x에 들어있는 숫자는
# 10입니다.

# %%
x = 10

if x == 10:
    print("x에 들어있는 숫자는") # 조건문 안에 들어있음
print("10입니다.") # 조건문 안에 들어가있지 않음
# Out:
# x에 들어있는 숫자는
# 10입니다.

# %%
x = 5

if x == 10:
    print("x에 들어있는 숫자는")
print("10입니다.")
# Out:
# 10입니다.

# %%
# 중첩 if 조건문 사용하기

# x = 15
# x = 10
x = 20


if x >= 10:
    print("10 이상입니다.")

    if x == 10:
        print("10 입니다.")
    if x == 20:
        print("20 입니다.")
# Out:
# 10 이상입니다.
# 20 입니다.

# %%
x = int(input("숫자를 입력하세요."))

if x == 10:
    print("10입니다.")
if x == 20:
    print("20입니다.")
# Out:
# 10입니다.

# %%
x = int(input())
y = input()

if y == "cash3000":
    print(x-3000)
if y == "cash5000":
    print(x-5000)
# Out:
# 24000
