# %%
# 사칙연산
# 주피터는 마지막 실행시 마지막 코드는 print를 사용하지 않아도 출력된다.

print(1 + 1)
1-1
print(2 * 2)
print(4 / 2)
#코드는 띄어쓰기를 권장(다른 코드 사용시 에러 확률이 있음)
4-4
# Out:
# 2
# 4
# 1.0

# %%
# 나눗셈 후 소수점 이하를 버리는 // 연산자(몫)
5 // 2
# Out:
# 2

# %%
# % 연산자 (나머지를 구하는 연산자)

5 % 2
# Out:
# 1

# %%
# ** (거듭 제곱을 구하는 연산자)
2 ** 10

#제곱근
4 ** 0.5
9 ** 0.5
# Out:
# 3.0

# %%
#값을 정수로 만들기

print(int(3.3))
int(4 / 2)
# Out:
# 3
# 2

# %%
# 객체의 자료형 알아내기(type)
print(type(10))
# Out:
# <class 'int'>

# %%
# 2 진수
0b110
(2**2 * 1)+(2**1 * 1)+(2**0 * 0)

0b111111
# Out:
# 63

# %%
#8진수
0O110
(8**2 * 1)+(8**1 * 1)+(8**0 * 0)
# Out:
# 72

# %%
#16진수
#A (10) B (11) C(12) D(13) E(14) F(15) G(16)
0XAF
(16**1 * 10) + (16**0 * 15)
# Out:
# 175

# %%
#실수 계산하기
3.5 + 2.1
# Out:
# 5.6

# %%
4.2 + 5
# Out:
# 9.2

# %%
#값을 실수로 만들기 (float)

float(5)
float()
float("5.3") #-> 문자열도 변화 가능
float("hi") #숫자로 이루어진 문자열만 변환 가능
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 6
#       2
#       3 float(5)
#       4 float()
#       5 float("5.3") #-> 문자열
# ----> 6 float("hi")
#
# ValueError: could not convert string to float: 'hi'

# %%
# 괄호 사용하기
print(2 + 2 * 2)
print((2 + 2) * 2)
# Out:
# 6
# 8

# %%
# #깃허브 연결 방법
# git init
# git add .
# git commit -m "처음 셋팅 0513"
# git remote add origin https://github.com/asmoon230/15-python-basic.git
# git push -u origin master
