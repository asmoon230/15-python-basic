# %%
# 문자열 바꾸기

"Hello, world!".replace("world", "Python")
# Out:
# 'Hello, Python!'

# %%
s = "Hello, world!"

s.replace("world", "Python")

print(s.replace("world", "Python"))
print(s)
# Out:
# Hello, Python!
# Hello, world!

# %%
a = [1, 2, 3, 4]
a.append(5)
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 문자 바꾸기

# table = "".maketrans("aeiou", "12345")
table = str.maketrans("aeiou", "12345")
"apple".translate(table)


# a = 1
# str(1)
# Out:
# '1ppl2'

# %%
# 문자열 분리하기
"apple pear grape pine apple orange".split()
# Out:
# ['apple', 'pear', 'grape', 'pine', 'apple', 'orange']

# %%
"apple,pear,grape,pineapple,orange".split(",")
# Out:
# ['apple', 'pear', 'grape', 'pineapple', 'orange']

# %%
# 구분자 문자열과 문자열 리스트 연결하기

" ".join(['apple', 'pear', 'grape', 'pineapple', 'orange'])
# Out:
# 'apple pear grape pineapple orange'

# %%
"-".join(['apple', 'pear', 'grape', 'pineapple', 'orange'])
# Out:
# 'apple-pear-grape-pineapple-orange'

# %%
#소문자를 대문자로 바꾸기

# upper("python")
"python".upper()
# Out:
# 'PYTHON'

# %%
# 대문자를 소문자로 바꾸기

print("PYTHON".lower())
print("PYTHON".lower().upper())
print("감사합니다".lower().upper())
# Out:
# python
# PYTHON
# 감사합니다

# %%
# 왼쪽 공백 삭제하기
"   python    ".lstrip()
# Out:
# 'python    '

# %%
# 오른쪽 공백 삭제하기

"   python    ".rstrip()
# Out:
# '   python'

# %%
# 양쪽 공백 삭제하기

"   python    ".strip()
# Out:
# 'python'

# %%
# 양쪽의 특정 문자 삭제하기
",. python ., ".strip(".,")



#
#
#
#
#
#
#
#
#
# Out:
# ' python ., '

# %%
# 문자열 왼쪽 정렬

"pythone".ljust(9)
# Out:
# 'pythone  '

# %%
# 문자열 오른쪽 정렬하기

"pythone".rjust(9)
# Out:
# '  pythone'

# %%
#문자열 가운데 정렬하기


"pythone".center(12)
# Out:
# '  pythone   '

# %%
# 문자열 왼쪽에 0채우기

print("35".zfill(4))
print("3.5".zfill(6))
print("hello".zfill(10))
# Out:
# 0035
# 0003.5
# 00000hello

# %%
#문자열 위치찾기

"apple pine apple".find("pl")
# Out:
# 2

# %%
"apple pine apple".find("xy")
# Out:
# -1

# %%
# 오른쪽에서 부터 문자열 찾기

"apple pine apple".rfind("pl")
# Out:
# 13

# %%
"apple pine apple".rfind("xy")
# Out:
# -1

# %%
# 문자열 위치 찾기 (index)

"apple pine apple".index("pl")
# Out:
# 2

# %%
"apple pine apple".index("xy")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 "apple pine apple".index("xy")
#
# ValueError: substring not found

# %%
"apple pine apple".rindex("pl")
# Out:
# 13

# %%
"apple pine apple".count("pl")
# Out:
# 2

# %%
# 문자열 서식 지정자와 포매팅 사용하기

# "%s" % "문자열"
"i am %s" % "james"
# Out:
# 'i am james'

# %%
name = "maria"

"i am %s" % name
# Out:
# 'i am maria'

# %%
# 서식 지정자로 숫자 넣기

# "%d" % 숫자

" i am %d years old" % 20
# Out:
# ' i am 20 years old'

# %%
# 서식 지정자로 소수점 표현하기
"%f" % 2.3
# Out:
# '2.300000'

# %%
"%.2f"%2.3
# Out:
# '2.30'

# %%
"%.3f"% 3
# Out:
# '3.000'

# %%
# 서식 지정자로 문자열 넣기

print("%10s"% "python")
print("%-10s"% "python")
# Out:
#     python
# python

# %%
# 서식 지정자로 문자열 안에 값 여러 개 넣기

"today is %d %s" % (3, "april")
# Out:
# 'today is 3 april'

# %%
"today is %d %s" % ("april",3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 "today is %d %s" % ("april",3)
#
# TypeError: %d format: a real number is required, not str

# %%
# format 매서드 사용하기


"hello, {0}".format("wolrd")
# Out:
# 'hello, wolrd'

# %%
"hello, {0} {1}".format("wolrd","!")
# Out:
# 'hello, wolrd !'

# %%
"hello, {0}".format("100")
# Out:
# 'hello, 100'

# %%
"hello, {0} {2} {1}".format("python","script",3.6)
# Out:
# 'hello, python 3.6 script'

# %%
"hello, {} {} {}".format("python", "script", 3.6)
# Out:
# 'hello, python script 3.6'

# %%
language = "python"
version = 3.6

f"hello, {language} {version}"
# `hello, {language} {version}` 자바스크립트 방법
# Out:
# 'hello, python 3.6'

# %%
# format 매서드로 문자열 정렬하기

"{0}".format("python")
# Out:
# 'python'

# %%
"{0:10}".format("python")
# Out:
# 'python    '

# %%
print("{0:<10}".format("python")) # -> 화살표를 의미
print("{0:>10}".format("python"))
# Out:
# python
#     python

# %%
# 숫자의 갯수 맞추기

print("%03d" % 1)
print("%02d" % 1)
print("%06d" % 1)
# Out:
# 001
# 01
# 000001

# %%
print("{:03d}".format(35))
print("{0:03d}".format(35))
# Out:
# 035
# 035

# %%
print("%f" % 3.6)
print("%8.2f" % 3.6)
print("%08.2f" % 3.6)
# Out:
# 3.600000
#     3.60
# 00003.60
