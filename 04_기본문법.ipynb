# %% [markdown]
# # 세미콜론
# ## 구문이 끝날 때;

# %%
# 주피터 

# 실행 : ctrl + enter
# 실행 + 셀추가 : shift + enter
# 셀추가 : a(위쪽), b(아래쪽)
# 셀삭제 : dd(빠르게)
# 주석처리 : ctrl + /
# 들여쓰기 : tab
# 여러줄 동시 입력 : ctrl + shift + alt
# 동시 수정 : 처음 수정위치를 누르고 두번째 부터 alt 누르고 더블클릭

# A = B + C

#읽는 순서는 C + B = A다

# %%
1+1
# Out:
# 2

# %%
# # 주석
# # 코드실행에 영향을 받지 않는다
# 빚얼 스튜디오 코드에서는 'ctrl+/' 설정이 가능하다(한 줄 주석, 블록 주석)

# %%
# 들여쓰기
# 공백 2칸 또는 공백 4칸
# 들여쓰기 자체가 문법이다.

# %%
# 코드 블록
## 들여쓰기를 기준으로 기준으로 코드 블록 구성
a=12

if a == 12:
    print("12 입니다.")
