# %%
a = [1, 2, 3]

dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
it = [1,2,3 ].__iter__()

# %%
it.__next__()
# Out:
# 1

# %%
it.__next__()
# Out:
# 2

# %%
it.__next__()
# Out:
# 3

# %%
it.__next__()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 it.__next__()
#
# StopIteration:

# %%
"hello, world!".__next__()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 "hello, world!".__next__()
#
# AttributeError: 'str' object has no attribute '__next__'

# %%
it = "hello, world!".__iter__()

# %%
it.__next__()
# Out:
# 'h'

# %%
print(list(it))
# Out:
# ['e', 'l', 'l', 'o', ',', ' ', 'w', 'o', 'r', 'l', 'd', '!']

# %%
# 이터레이터 만들기

# class 이터레이터이름:
#     def __iter__(self):
#         코드
#     def __next__(self):
#         코드

class Counter:
    def __init__(self, stop):
        self.current = 0
        self.stop = stop
    def __iter__(self):
        return self
    def __next__(self):
        if self.current < self.stop:
            r = self.current
            self.current += 1
            return r
        else:
            raise StopIteration

# %%
for i in Counter(3):
    print (i, end = " ")
# Out:
# 0 1 2

# %%
# 이터레이터 언패킹

print(*Counter(3))
# Out:
# 0 1 2

# %%
a, b, c = Counter(3)
print(a, b, c)
# Out:
# 0 1 2

# %%
_, _, c = Counter(3)
print(c)
# Out:
# 2

# %%
# 인덱스로 접근할 수 있는 이터레이터 만들기

# class 이터레이터:
#     def __getitem__(self,인덱스):
#         코드

class Counter:
    def __init__(self, stop):
        self.stop = stop
    def __getitem__(self, index):
        if index < self.stop:
            return index
        else:
            raise IndexError
        
print(Counter(3)[0])
print(Counter(3)[1])
print(Counter(3)[2])
print(Counter(3)[3])
# Out:
# 0
# 1
# 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 19
#      15
#      16 print(Counter(3)[0])
#      17 print(Counter(3)[1])
#      18 print(Counter(3)[2])
# ---> 19 print(Counter(3)[3])
#
# Cell In[25], line 14, in Counter.__getitem__(self, index)
#      10     def __getitem__(self, index):
#      11         if index < self.stop:
#      12             return index
#      13         else:
# ---> 14             raise IndexError
#
# IndexError:

# %%
# iter 함수
a = iter(range(3))
print(next(a))
print(next(a))
print(next(a))
print(next(a,-100))
# Out:
# 0
# 1
# 2
# -100

# %%
# Out:
# 0
