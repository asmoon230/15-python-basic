# %%
# while 조건문: # 불리안이 나오는 조건문
#     반복할 코드

i = 0

while i < 10:
    print("hello world")
    i += 1

# %%
# 초기 값을 1부터 시작하기

i = 1

while i <= 10:
    print("hello world")
    i += 1

# %%
# 초깃값을 감소시키기

i = 10
while i>0:
    print ("hello world")
    i -= 1

# %%
# 입력한 횟수대로 반복하기

count = int(input("반복할 횟수를 입력하세요 : "))

i = 0

while i < count:
    print("hello world",i)
    i += 1
# Out:
# hello world 0

# %%
import random

# %%
random.random()

# %%
random.randint(1,10)

# %%
import random

i = 0

while i != 3:
    i = random.randint(1,6)
    print(i)

# %%
while True:
    print("hello world")

# %%
c = int(input())

while c > 1350:
    c -= 1350
    print(c)
# Out:
# 8650
# 7300
# 5950
# 4600
# 3250
# 1900
# 550
