# %%
# 재귀호출 사용하기

def hello():
    print("hello")
    hello()

# %%
hello()
# Out:
# hello

# %%
def hello(count):
    if count == 0:
        return 50
    
    print("hello world", count)

    count -= 1
    hello(count)

# %%
print(hello(1))
# Out:
# hello world 1
# None

# %%
hello(2):
    print("hello world", 2)

    count -= 1
    return hello(1)

hello(1):
    print("hello world", 1)

    count -= 1
    return hello(0)

hello(0):
    if count == 0:
        return 50

print h2 = 50
print h1 = 50

# %%
    hello(1):
        print("hello world", 1)
        count -= 1
            hello(0):
                    if count == 0:
                       return 50

print h(2) = None
print h(1) = 50

# %%
# print(hello(0))
print(hello(2))
# Out:
# hello world 2
# hello world 1
# 50

# %%
# 재귀호출로 팩토리얼 구하기

def factolail(n):
    if n == 1:
        return 1
    return n * factolail(n-1)

# %%
factolail(5)
# Out:
# 120
