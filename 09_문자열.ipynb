# %%
hello = "Heoll world!"
hello
# Out:
# 'Heoll world!'

# %%
hello = "안녕하세요." 
hello
# Out:
# '안녕하세요.'

# %%
hello = '''Hello world!'''
hello
# Out:
# 'Hello world!'

# %%
python = '''python programming'''
python
# Out:
# 'python programming'

# %%
# 여러줄로 된 문자열 사용하기
hello = '''Hello world!
안녕하세요
Python입니다.'''
print(hello)

s = """이
상
하
다"""
print(s)
# Out:
# Hello world!
# 안녕하세요
# Python입니다.
# 이
# 상
# 하
# 다

# %%
# 문자열 안에 작은 따옴표나 큰 따옴표 포함하기

s = "Python isn't difficult"
s
# Out:
# "Python isn't difficult"

# %%
s = 'he said "Python is easy"'
s
# Out:
# 'he said "Python is easy"'

# %%
# 탈출 문자 (excaipe code)
s = "he \'sa\nid \"Python \tis \\easy\""
print(s)
# Out:
# he 'sa
# id "Python 	is \easy"

# %%
s = '''Python is a programming language thet lets you work quickly
and
integrate systems mor effectively'''

print(s)
# Out:
# Python is a programming language thet lets you work quickly
# and
# integraten systems mor effectively

# %%
n = '\'Python\' is a "programing languare"\nthat lets you work quickly\nand\nintegrate systems more effectively.'
print(n)
# Out:
# 'Python' is a "programing languare"
# that lets you work quickly
# and
# integrate systems more effectively.
